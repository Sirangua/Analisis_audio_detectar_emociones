# %%
import pandas as pd
import matplotlib.pyplot as plt

# %%
anger_stats = pd.read_csv ('Stats_anger_fourier.csv')
disgust_stats = pd.read_csv ('Stats_disgust_fourier.csv')
fear_stats = pd.read_csv ('Stats_fear_fourier.csv')
happiness_stats = pd.read_csv ('Stats_happiness_fourier.csv')
neutral_stats = pd.read_csv ('Stats_neutral_fourier.csv')
sadness_stats = pd.read_csv ('Stats_sadness_fourier.csv')
surprise_stats = pd.read_csv ('Stats_surprise_fourier.csv')

# %% [markdown]
# ### First moment

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['M1'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['M1'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['M1'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['M1'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['M1'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['M1'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['M1'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('First Moment', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("M1", fontsize = 13)

plt.savefig ("M1_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1320731938.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("M1_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Second moment

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['M2'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['M2'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['M2'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['M2'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['M2'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['M2'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['M2'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Second Moment', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("M2", fontsize = 13)

plt.savefig ("M2_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\4046637495.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("M2_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Third moment

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['M3'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['M3'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['M3'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['M3'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['M3'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['M3'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['M3'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Third Moment', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("M3", fontsize = 13)

plt.savefig ("M3_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1040660132.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("M3_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Fourth moment

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['M4'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['M4'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['M4'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['M4'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['M4'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['M4'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['M4'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Fourth Moment', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("M4", fontsize = 13)

plt.savefig ("M4_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\3817498231.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("M4_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Second cumulant

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['C2'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['C2'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['C2'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['C2'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['C2'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['C2'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['C2'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Second cumulant', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("C2", fontsize = 13)

plt.savefig ("C2_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\3830937368.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("C2_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Third cumulant

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['C3'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['C3'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['C3'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['C3'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['C3'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['C3'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['C3'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Third cumulant', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("C3", fontsize = 13)

plt.savefig ("C3_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\3346125423.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("C3_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Fourth cumulant

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['C4'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['C4'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['C4'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['C4'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['C4'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['C4'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['C4'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Fourth Cumulant', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("C4", fontsize = 13)

plt.savefig ("C4_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\3043442443.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("C4_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Skewness

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Skewness'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Skewness'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Skewness'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Skewness'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Skewness'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Skewness'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Skewness'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Skewness', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Skewness", fontsize = 13)

plt.savefig ("Skewness_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\4166776242.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Skewness_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Kurtosis

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Kurtosis'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Kurtosis'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Kurtosis'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Kurtosis'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Kurtosis'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Kurtosis'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Kurtosis'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Kurtosis', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Kurtosis", fontsize = 13)

plt.savefig ("Kurtosis_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1402557497.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Kurtosis_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Mean

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Mean'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Mean'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Mean'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Mean'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Mean'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Mean'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Mean'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Mean', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Mean", fontsize = 13)

plt.savefig ("Mean_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\4037419429.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Mean_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Absolute mean

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Absolute_mean'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Absolute_mean'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Absolute_mean'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Absolute_mean'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Absolute_mean'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Absolute_mean'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Absolute_mean'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Absolute mean', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Absolute_mean", fontsize = 13)

plt.savefig ("Absolute_mean_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\788075554.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Absolute_mean_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Peak value

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Peak_value'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Peak_value'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Peak_value'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Peak_value'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Peak_value'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Peak_value'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Peak_value'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Peak value', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Peak value", fontsize = 13)

plt.savefig ("Peak_value_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1723094399.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Peak_value_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Square root value

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['SRV'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['SRV'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['SRV'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['SRV'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['SRV'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['SRV'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['SRV'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Square root value', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("SRV", fontsize = 13)

plt.savefig ("SRV_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1531149310.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("SRV_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Root mean square

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['RMS'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['RMS'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['RMS'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['RMS'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['RMS'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['RMS'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['RMS'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Root mean square', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("RMS", fontsize = 13)

plt.savefig ("RMS_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\341511582.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("RMS_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Crest factor

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Crest_factor'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Crest_factor'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Crest_factor'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Crest_factor'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Crest_factor'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Crest_factor'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Crest_factor'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Crest factor', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Crest_factor", fontsize = 13)

plt.savefig ("Crest_factor_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1720652669.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Crest_factor_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)

# %% [markdown]
# ### Shape factor

# %%
plt.scatter(anger_stats['Unnamed: 0'], anger_stats['Shape_factor'], color = 'red', label = "Angry")
plt.scatter(disgust_stats['Unnamed: 0'], disgust_stats['Shape_factor'], color = 'olive', label = "Disgust")
plt.scatter(fear_stats['Unnamed: 0'], fear_stats['Shape_factor'], color = 'green', label = "Fear")
plt.scatter(happiness_stats['Unnamed: 0'], happiness_stats['Shape_factor'], color = 'darkviolet', label = "Happiness")
plt.scatter(sadness_stats['Unnamed: 0'], sadness_stats['Shape_factor'], color = 'darkturquoise', label = "Sadness")
plt.scatter(surprise_stats['Unnamed: 0'], surprise_stats['Shape_factor'], color = 'gold', label = "Surprise")
plt.scatter(neutral_stats['Unnamed: 0'], neutral_stats['Shape_factor'], color = 'deeppink', label = "Neutral")

plt.axvline(x = 14, color = 'dimgray', label = 'Person 1', linestyle = 'solid', linewidth = '1')
plt.axvline(x = 29, color = 'dimgray', label = 'Person 2', linestyle = 'dashdot', linewidth = '1')
plt.axvline(x = 44, color = 'dimgray', label = 'Person 3', linestyle = 'dashed', linewidth = '1')
plt.axvline(x = 59, color = 'dimgray', label = 'Person 4', linestyle = 'dotted', linewidth = '1')

plt.legend (loc = (1.005,0))
plt.suptitle('Shape factor', fontsize = 20)
plt.xlabel ("Audio sample", fontsize = 13)
plt.ylabel ("Shape_factor", fontsize = 13)

plt.savefig ("Shape_factor_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
# Out:
# C:\Users\emma\AppData\Local\Temp\ipykernel_8580\1814745546.py:19: MatplotlibDeprecationWarning: savefig() got unexpected keyword argument "quality" which is no longer supported as of 3.3 and will become an error in 3.6
#   plt.savefig ("Shape_factor_graph_fourier.jpg", bbox_inches="tight", quality = 100, dpi = 300)
